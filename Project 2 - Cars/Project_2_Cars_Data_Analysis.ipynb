# %% [markdown]
# <a href="https://colab.research.google.com/github/Yarin-Shohat/Data-Anlysis-Projects/blob/main/Project%202%20-%20Cars/Project_2_Cars_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Working on Real Project with Python**

# %% [markdown]
# # Cars Dataset
# ***
# Here,
# The data of different cars is given with their specifications.
#
#
# This data is available as a CSV file. We are going to analyze this data set using the Pandas DataFrame.

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Read Data with Pandas

# %%
data = pd.read_csv("/content/Project 2 - Cars Dataset.csv")

# %% [markdown]
# Show the Data

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        17         23.0
# 1    $21,761          2.0        4.0         200        24         31.0
# 2    $24,647          2.4        4.0         200        22         29.0
# 3    $30,299          3.2        6.0         270        20         28.0
# 4    $39,014          3.5        6.0         225        18         24.0
# ..        ...         ...        ...         ...       ...          ...
# 423  $38,203          2.4        5.0         197        21         28.0
# 424  $40,083          2.3        5.0         242        20         26.0
# 425  $42,573          2.9        6.0         268        19         26.0
# 426  $24,641          1.9        4.0         170        22         29.0
# 427  $33,112          2.5        5.0         208        20         27.0
#
#      Weight  Wheelbase  Length
# 0      4451      106.0   189.0
# 1      2778      101.0   172.0
# 2      3230      105.0   183.0
# 3      3575      108.0   186.0
# 4      3880      115.0   197.0
# ..      ...        ...     ...
# 423    3450      105.0   186.0
# 424    3450      105.0   186.0
# 425    3653      110.0   190.0
# 426    2822      101.0   180.0
# 427    3823      109.0   186.0
#
# [428 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower       int64
# MPG_City         int64
# MPG_Highway    float64
# Weight           int64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  427.000000  422.000000  428.000000  428.000000   427.000000
# mean     3.196721    5.805687  215.885514   20.060748    26.843091
# std      1.109895    1.559635   71.836032    5.238218     5.747930
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.350000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  426.000000  427.000000
# mean   3577.953271  108.159624  186.348946
# std     758.983215    8.328427   14.372232
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# max    7190.000000  144.000000  238.000000

# %% [markdown]
# # 1) Instruction ( For Data Cleaning )
# - Find all Null Values in the dataset. If there is any null value in any column, then fill it with the mean of that column.

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     1
# Cylinders      6
# Horsepower     0
# MPG_City       0
# MPG_Highway    1
# Weight         0
# Wheelbase      2
# Length         1
# dtype: int64

# %%
null_columns = data.columns[data.isnull().sum()>0]
null_columns
# Out:
# Index(['EngineSize', 'Cylinders', 'MPG_Highway', 'Wheelbase', 'Length'], dtype='object')

# %%
for col in null_columns:
  data[col].fillna(data[col].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # 2) Question ( Based on Value Counts )
# - Check what are the different types of Make are there in our dataset. And, what is the count (occurrence) of each Make in the data
# ?

# %%
data['Make'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
data['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # 3) Instruction ( Filtering )
# - Show all the records where Origin is Asia or Europe.

# %%
data[(data['Origin'] == 'Asia') | (data['Origin'] == 'Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        17         23.0
# 1    $21,761          2.0        4.0         200        24         31.0
# 2    $24,647          2.4        4.0         200        22         29.0
# 3    $30,299          3.2        6.0         270        20         28.0
# 4    $39,014          3.5        6.0         225        18         24.0
# ..        ...         ...        ...         ...       ...          ...
# 423  $38,203          2.4        5.0         197        21         28.0
# 424  $40,083          2.3        5.0         242        20         26.0
# 425  $42,573          2.9        6.0         268        19         26.0
# 426  $24,641          1.9        4.0         170        22         29.0
# 427  $33,112          2.5        5.0         208        20         27.0
#
#      Weight  Wheelbase  Length
# 0      4451      106.0   189.0
# 1      2778      101.0   172.0
# 2      3230      105.0   183.0
# 3      3575      108.0   186.0
# 4      3880      115.0   197.0
# ..      ...        ...     ...
# 423    3450      105.0   186.0
# 424    3450      105.0   186.0
# 425    3653      110.0   190.0
# 426    2822      101.0   180.0
# 427    3823      109.0   186.0
#
# [281 rows x 15 columns]

# %% [markdown]
# ----

# %% [markdown]
# # 4) Instruction ( Removing unwanted records )
# - Remove all the records (rows) where Weight is above 4000.

# %%
data[~(data['Weight'] > 4000)]
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        17         23.0
# 1    $21,761          2.0        4.0         200        24         31.0
# 2    $24,647          2.4        4.0         200        22         29.0
# 3    $30,299          3.2        6.0         270        20         28.0
# 4    $39,014          3.5        6.0         225        18         24.0
# ..        ...         ...        ...         ...       ...          ...
# 423  $38,203          2.4        5.0         197        21         28.0
# 424  $40,083          2.3        5.0         242        20         26.0
# 425  $42,573          2.9        6.0         268        19         26.0
# 426  $24,641          1.9        4.0         170        22         29.0
# 427  $33,112          2.5        5.0         208        20         27.0
#
#      Weight  Wheelbase  Length
# 0      4451      106.0   189.0
# 1      2778      101.0   172.0
# 2      3230      105.0   183.0
# 3      3575      108.0   186.0
# 4      3880      115.0   197.0
# ..      ...        ...     ...
# 423    3450      105.0   186.0
# 424    3450      105.0   186.0
# 425    3653      110.0   190.0
# 426    2822      101.0   180.0
# 427    3823      109.0   186.0
#
# [428 rows x 15 columns]

# %% [markdown]
# -----

# %% [markdown]
# # 5) Instruction ( Applying function on a column )
# - Increase all the values of 'MPG_City' column by 3.

# %%
data['MPG_City'] = data['MPG_City'].apply(lambda x:x+3)
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        20         23.0
# 1    $21,761          2.0        4.0         200        27         31.0
# 2    $24,647          2.4        4.0         200        25         29.0
# 3    $30,299          3.2        6.0         270        23         28.0
# 4    $39,014          3.5        6.0         225        21         24.0
# ..        ...         ...        ...         ...       ...          ...
# 423  $38,203          2.4        5.0         197        24         28.0
# 424  $40,083          2.3        5.0         242        23         26.0
# 425  $42,573          2.9        6.0         268        22         26.0
# 426  $24,641          1.9        4.0         170        25         29.0
# 427  $33,112          2.5        5.0         208        23         27.0
#
#      Weight  Wheelbase  Length
# 0      4451      106.0   189.0
# 1      2778      101.0   172.0
# 2      3230      105.0   183.0
# 3      3575      108.0   186.0
# 4      3880      115.0   197.0
# ..      ...        ...     ...
# 423    3450      105.0   186.0
# 424    3450      105.0   186.0
# 425    3653      110.0   190.0
# 426    2822      101.0   180.0
# 427    3823      109.0   186.0
#
# [428 rows x 15 columns]

# %% [markdown]
# ----
